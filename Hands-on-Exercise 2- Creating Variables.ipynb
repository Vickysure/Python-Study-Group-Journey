# %% [markdown]
# ## Exercise 1: Creating Variables

# %%
name = "Ukachi Victor"
age = "27"
country = "Nigeria"
print (name)
print (age)
print (country)
# Out:
# Ukachi Victor
# 27
# Nigeria

# %% [markdown]
# ## Exercise 2: Salary calculation

# %%
employee_basic_salary = 180000
employee_bonus = 35000
employee_total_salary = (employee_basic_salary + employee_bonus)
print ("Employee_basic_salary:" , employee_basic_salary)
print ("Employee_bonus:" , employee_bonus)
print ("Employee_total_salary:" , employee_total_salary)
# Out:
# Employee_basic_salary: 180000
# Employee_bonus: 35000
# Employee_total_salary: 215000

# %% [markdown]
# ## Exercise 3: User Input

# %%
name = input ("Enter your name:")
favorite_programming_language = input ("Enter your favorite programming Language:")
print ("Hello" ,name)
print ("Your Favorite Programming Language is" , favorite_programming_language)
# Out:
# Enter your name: Segun
# Enter your favorite programming Language: Python
# Hello Segun
# Your Favorite Programming Language is Python

# %% [markdown]
# ## Exercise 4:Working with Data Types

# %%
a = 10
b = 21.00
c = "Victor"
is_valid = False
print (type(a))
print (type(b))
print (type(c))
print (type(is_valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Exercise 5: Dynamic Typing

# %%
a = 1050
print (type(a))
# Out:
# <class 'int'>

# %%
a = "Victor"
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# ## Mini Project: Student Information Card

# %%
project_name = "STUDENT INFORMATION CARD"
task_2 = "DATA TYPE"
name = input ("Enter your name:")
age = input ("Enter your age:")
course = input ("Enter your course:")
country = input ("Enter your country:")
print (project_name)
print ("Name:" ,name)
print ("Age:" ,age)
print ("Course:" ,course)
print ("Country:" ,country)
print (task_2)
print (type(name))
print (type(age))
print (type(course))
print (type(country))
# Out:
# Enter your name: Ukachi Victor
# Enter your age: 27
# Enter your course: Python Programming
# Enter your country: Nigeria
# STUDENT INFORMATION CARD
# Name: Ukachi Victor
# Age: 27
# Course: Python Programming
# Country: Nigeria
# DATA TYPE
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ## Bonus Challenge

# %%
project_name = "STUDENT INFORMATION CARD"
task_2 = "DATA TYPE"
name = input ("Enter your name:")
age = int(input ("Enter your age:"))
course = input ("Enter your course:")
country = input ("Enter your country:")
print (project_name)
print ("Name:" ,name)
print ("Age:" ,age)
print ("Course:" ,course)
print ("Country:" ,country)
print (task_2)
print (type(name))
print (type(age))
print (type(course))
print (type(country))
# Out:
# Enter your name: Ukachi Victor
# Enter your age: 27
# Enter your course: Python Programming
# Enter your country: Nigeria
# STUDENT INFORMATION CARD
# Name: Ukachi Victor
# Age: 27
# Course: Python Programming
# Country: Nigeria
# DATA TYPE
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ## Thank You so Much coach, this assignment was really brain tasking. I made a lot of errors, but I was able to fix the errors.
