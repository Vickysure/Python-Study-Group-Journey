# %% [markdown]
# ## Question 1: Secure Login System

# %%
# This is a code for Employee portal Login Module
username_correct = True
password_correct = True
account_locked = False
print ("Access Granted:", ( username_correct and password_correct and  (not account_locked)))
# Out:
# Access Granted: True

# %% [markdown]
# ## Question 2: University Scholarship Eligibility

# %%
# This code is for Scholarship Qualification Requirement
name = input ("Student name:")
score = 85
participated = True
low_income = False
print ("Congratulations!", name)
print ("Scholarship Approval Status:", ((score >= 80) and (participated or low_income)))
# Out:
# Student name: Benjamin
# Congratulations! Benjamin
# Scholarship Approval Status: True

# %%
# this line is a comment to try High score with no participation and no low income
name = input ("Student name:")
score = 85
participated = True
low_income = False
print ("We are Sorry", name)
print ("Scholarship Approval Status:", ((score >= 80) and ((not participated) and low_income)))
print ("The Scholarship Approval Status is False ; student didn't meet the requirement of either participation or low income category")
# Out:
# Student name: Adeyinka
# We are Sorry Adeyinka
# Scholarship Approval Status: False
# The Scholarship Approval Status is False ; student didn't meet the requirement of either participation or low income category

# %%
# this line is a comment to try Low Score with Extral curriclum participation 
name = input ("Student name:")
score = 79
participated = True
low_income = False
print ("We are Sorry", name)
print ("Scholarship Approval Status:", ((score >= 80) and  participation))
print ("The Scholarship Approval Status is false ; student score is not greater than or equal to 80")
# Out:
# Student name: Wisdom
# We are Sorry Wisdom
# Scholarship Approval Status: False
# The Scholarship Approval Status is false ; student score is not greater than or equal to 80

# %%
# this line is a comment to try High Score and Low Income
name = input ("Student name:")
score = 85
participated = True
low_income = False
print ("Congratulations!", name)
print ("Scholarship Approval Status:", ((score >= 80) and (not low_income)))
print ("Scholarship Approval Status is True ; student passed criterial of high score and low income")
# Out:
# Student name: Demilade
# Congratulations! Demilade
# Scholarship Approval Status: True
# Scholarship Approval Status is True ; student passed criterial of high score and low income

# %%
# this line is a comment to try High Score with student participation and low income
name = input ("Student name:")
score = 85
participated = True
low_income = True
print ("Congratulations!", name)
print ("Scholarship Approval Status:", ((score >= 80) and (participated or low_income)))
print ("Scholarship Approval Status is True ; Student pass the scholarship requirement")
# Out:
# Student name: Bamidele
# Congratulations! Bamidele
# Scholarship Approval Status: True
# Scholarship Approval Status is True ; Student pass the scholarship requirement

# %% [markdown]
# ## Question 3: Smart Server Health Monitor

# %%
# This line is a comment: memory is above threshold
cpu_usage = 75
memory_usage = 92
disk_usage = 60
print ("Critical Alert:", ((cpu_usage > 90) or (memory_usage > 90) or (disk_usage > 90)))
print ("System Healthy:", ((cpu_usage < 90) and (memory_usage < 90) and (disk_usage < 90)))
# Out:
# Critical Alert: True
# System Healthy: False

# %%
# This line is a comment: All Resources are below threshold
cpu_usage = 75
memory_usage = 89
disk_usage = 60
print ("Critical Alert:", ((cpu_usage > 90) or (memory_usage > 90) or (disk_usage > 90)))
print ("System Healthy:", ((cpu_usage < 90) and (memory_usage < 90) and (disk_usage < 90)))
# Out:
# Critical Alert: False
# System Healthy: True

# %%
# This line is a comment : CPU usage Exceeds Threshold
cpu_usage = 95
memory_usage = 89
disk_usage = 60
print ("Critical Alert:", ((cpu_usage > 90) or (memory_usage > 90) or (disk_usage > 90)))
print ("System Healthy:", ((cpu_usage < 90) and (memory_usage < 90) and (disk_usage < 90)))
# Out:
# Critical Alert: True
# System Healthy: False

# %%
# This line is a comment : Disk usage Exceeds Threshold
cpu_usage = 85
memory_usage = 89
disk_usage = 95
print ("Critical Alert:", ((cpu_usage > 90) or (memory_usage > 90) or (disk_usage > 90)))
print ("System Healthy:", ((cpu_usage < 90) and (memory_usage < 90) and (disk_usage < 90)))
# Out:
# Critical Alert: True
# System Healthy: False

# %%
# This line is a comment : All three Resources Exceeds Threshold
cpu_usage = 95
memory_usage = 96
disk_usage = 93
print ("Critical Alert:", ((cpu_usage > 90) or (memory_usage > 90) or (disk_usage > 90)))
print ("System Healthy:", ((cpu_usage < 90) and (memory_usage < 90) and (disk_usage < 90)))
# Out:
# Critical Alert: True
# System Healthy: False

# %% [markdown]
# ## Question 4: Bonus Challenge

# %%
# this a comment : customer allowed to place requirements
logged_in = True
stock = 100
sold = 58
stock_balance = stock - sold
item_in_stock = (stock_balance >= 1)
saved_payment_method = True
wallet_balance = 5000
enough_wallet_balance = (wallet_balance >= 1000)
account_suspended = False
print (" Order Confirmed!", (logged_in and item_in_stock and (saved_payment_method or enough_wallet_balance) and (not account_suspended)))
# Out:
#  Order Confirmed! True

# %% [markdown]
# ### Order confirmed is true because all requiremnts for a purchase were met

# %%
# this a comment : customer allowed to place requirements
logged_in = True
stock = 100
sold = 91
stock_balance = stock - sold
item_in_stock = (stock_balance >= 10)
saved_payment_method = False
wallet_balance = 5000
enough_wallet_balance = (wallet_balance >= 1000)
account_suspended = False
print (" Order Confirmed!", (logged_in and item_in_stock and (saved_payment_method or enough_wallet_balance) and (not account_suspended)))
# Out:
#  Order Confirmed! False

# %% [markdown]
# #### Order Confirmed is false because stock balance is less than 10, meaning the item to be purchased is not in stock, leading to a failed order. I hope you understand Coach. I don't know the exact way you want us to explain our solutions

# %%
# this a comment : customer allowed to place requirements
logged_in = True
stock = 100
sold = 30
stock_balance = stock - sold
item_in_stock = (stock_balance >= 10)
saved_payment_method = False
wallet_balance = 500
enough_wallet_balance = (wallet_balance >= 1000)
account_suspended = False
print (" Order Confirmed!", (logged_in and item_in_stock and (saved_payment_method or enough_wallet_balance) and (not account_suspended)))
# Out:
#  Order Confirmed! False

# %% [markdown]
# ### Order confirmed is false because all requiremnts for a purchase to be made are not met, as both saved payment method and enough wallet balance are false.

# %% [markdown]
# ### Thank you coach, this has been the most challenging task for me so far, I just hope I did it right. Somewhere within me, I Feel like there's more to be done than what I've done.
