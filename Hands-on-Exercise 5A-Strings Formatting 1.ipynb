# %% [markdown]
# ## Ex 1: CUSTOMER REGISTRATION SYSTEM

# %%
# The code below is to create variables for the customer
customer_name = "David Sunday"
email_address = "davidsunday@gmail.com"
phone_number = "+2348072345678"
country = "Nigeria"
occupation = "Trader"

print ("     CUSTOMER REGISTRATION")
print ("                               ")
print ("Name:", customer_name)
print ("Email:", email_address)
print ("Phone:", phone_number)
print ("Country:", country)
print ("Occupation:", occupation)
# Out:
#      CUSTOMER REGISTRATION
#
# Name: David Sunday
# Email: davidsunday@gmail.com
# Phone: +2348072345678
# Country: Nigeria
# Occupation: Trader

# %% [markdown]
# ## Ex 2: HOSPITAL PATIENT RECORD

# %%
# The code below is to create a patient record
patient_name = "Dusk"
doctor = "Dr.Praise"
diagnosis = "+ve case"
blood_group = "O positive (O+)"
hospital = "General Hospital"

print ("PATIENT RECORD")
print ("                        ")
print ("Patient:", patient_name)
print ("Doctor:", doctor)
print ("Diagnosis:", diagnosis)
print ("Blood Group:", blood_group)
print ("Hospital:", hospital)
print ("                                 ")
print ("                                 ")
print ("=================================")
print ("       BONUS CHALLENGE")
print ("=================================")
print ("                                 ")
print ("""PATIENT RECORD

Patient: Dusk
Doctor: Dr. Praise
Diagnosis: +ve case
Blood Group: O Postive (O+)
Hospital: General Hospital
""")
print ("============================")
# Out:
# PATIENT RECORD
#
# Patient: Dusk
# Doctor: Dr.Praise
# Diagnosis: +ve case
# Blood Group: O positive (O+)
# Hospital: General Hospital
#
#
# ...
#        BONUS CHALLENGE
# ...
#
# PATIENT RECORD
#
# Patient: Dusk
# Doctor: Dr. Praise
# Diagnosis: +ve case
# Blood Group: O Postive (O+)
# Hospital: General Hospital
#
# ...

# %% [markdown]
# ## Ex3: AI PROMPT BUILDER

# %%
# the code below is to display an Ai prompt
print ("    AN AI PROMPT")
print ("                                       ")
prompt = """You are an AI Assistant.
complete the following task:

-Analyze customer feedback.

-Identify common complaints.

-Provide recommendations.

-Generate a summary report.
"""

print (prompt)
print ("                                    ")
print ("====================================")
print ("       BONUS CHALLENGE")
print ("====================================")
print ("                                   ")
print ("    NEW AI PROMPT")
print ("                                  ")
prompt2 = """You are an AI Assistant.
complete the following task:

-Provide the average volume of Data suncriptions.

-Identify the total number of customers active

-Analyze customer feedback.

-Identify common complaints.

-Provide recommendations.

-Generate a summary report.
"""
print (prompt2)
# Out:
#     AN AI PROMPT
#
# You are an AI Assistant.
# complete the following task:
#
# -Analyze customer feedback.
#
# -Identify common complaints.
#
# -Provide recommendations.
#
# -Generate a summary report.
#
#
# ...
#        BONUS CHALLENGE
# ...
#
#     NEW AI PROMPT
#
# You are an AI Assistant.
# complete the following task:
#
# -Provide the average volume of Data suncriptions.
#
# -Identify the total number of customers active
#
# -Analyze customer feedback.
#
# -Identify common complaints.
#
# -Provide recommendations.
#
# -Generate a summary report.

# %% [markdown]
# ## Ex4: CUSTOMER FEEDBACK MANAGEMENT SYSTEM

# %%
# the code below is to display a customer's feedback
customer_name = "Sonia Justice"
product = "Bluetooth Headset"
category = "Sound Accessories"
rating  = "4 Stars"
customer_review = """The product arrived a bit late, sound quality is good, 
product material not so durable. 
It seems to be water resistant, but
I may not recommend it to others
"""
print ("===========================================")
print ("    CUSTOMER FEEDBACK REPORT")
print ("===========================================")
print ("                                     ")
print ("Customer Name:", customer_name)
print ("Product:", product)
print ("Product Category:", category)
print ("Customer Rating:", rating)
print ("                           ")
print ("Customer Review")
print ("--------------------------")
print (customer_review)
print ("                                    ")
print ("============================================")
print ("   Thank You for Your Feedback")
print ("============================================")
# Out:
# ...
#     CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sonia Justice
# Product: Bluetooth Headset
# Product Category: Sound Accessories
# Customer Rating: 4 Stars
#
# Customer Review
# --------------------------
# The product arrived a bit late, sound quality is good,
# product material not so durable.
# It seems to be water resistant, but
# I may not recommend it to others
#
#
# ...
#    Thank You for Your Feedback
# ...

# %% [markdown]
# ## BONUS CHALLENGE of Ex 4

# %%
# the code below is to display a customer's feedback
customer_name = "Sonia Justice"
product = "Bluetooth Headset"
category = "Sound Accessories"
rating  = "4 Stars"
customer_review = """The product arrived a bit late, 
you need to work on your team's delivery time.
This your product is giving me the vibes of,
"what I bought vs what I got"
Although sound quality is good, 
but your product material is not so durable. 
It seems to be 'water resistant' however, but in all,
I may not recommend it to others
"""
company_name = 'VICKYSURE\'s GADGETS & ACCESSORIES'
support_email = "vickysuregadgets@gmail.com"
welcome_message = '''Hello!, Welcome to Vickysure Gadgets & Accessories.
What do you wish to buy from Us today?
'''
print ("                                          ")
print (welcome_message)
print ("                                             ")
print ("===========================================")
print ("    CUSTOMER FEEDBACK REPORT")
print ("===========================================")
print ("                                     ")
print ("Customer Name:", customer_name)
print ("Product:", product)
print ("Product Category:", category)
print ("Customer Rating:", rating)
print ("                           ")
print ("Customer Review")
print ("--------------------------")
print (customer_review)
print ("                                    ")
print ("============================================")
print ("   Thank You for Your Feedback")
print ("============================================")
print ("      ", company_name)
print ("   Support Email:", support_email)
# Out:
#
# Hello!, Welcome to Vickysure Gadgets & Accessories.
# What do you wish to buy from Us today?
#
#
# ...
#     CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sonia Justice
# Product: Bluetooth Headset
# Product Category: Sound Accessories
# Customer Rating: 4 Stars
#
# Customer Review
# --------------------------
# The product arrived a bit late,
# you need to work on your team's delivery time.
# This your product is giving me the vibes of,
# "what I bought vs what I got"
# Although sound quality is good,
# but your product material is not so durable.
# It seems to be 'water resistant' however, but in all,
# I may not recommend it to others
#
#
# ...
#    Thank You for Your Feedback
# ...
#        VICKYSURE's GADGETS & ACCESSORIES
#    Support Email: vickysuregadgets@gmail.com

# %% [markdown]
# #####         Thank You Coach, Once Again!
