# %% [markdown]
# ## Exercise 1: Printing Text

# %%
print ("Hello, World!")
print ("My name is Ukachi Victor")
print ("I'm learning Python")
print ("Programming is exciting")
# Out:
# Hello, World!
# My name is Ukachi Victor
# I'm learning Python
# Programming is exciting

# %% [markdown]
# ## Exercise 2: Multiple Print Statements

# %%
print ("my favorite food is Rice")
print ("my favorite movie is James Bond")
print ("my favorite sport is Football")
print ("my favorite color is Black")
# Out:
# my favorite food is Rice
# my favorite movie is James Bond
# my favorite sport is Football
# my favorite color is Black

# %% [markdown]
# ## Exercise 3: python Calculator

# %%
print (15+5)
# Out:
# 20

# %%
print (30-12)
# Out:
# 18

# %%
print (9*8)
# Out:
# 72

# %%
print (72/9)
# Out:
# 8.0

# %%
print (18%5)
# Out:
# 3

# %%
print (10//3)
# Out:
# 3

# %%
print (5**2)
# Out:
# 25

# %% [markdown]
# ## Exercise 4 : Understnading comments

# %%
# This line is a Comment, to display programming language
print ("python")
# Out:
# python

# %% [markdown]
# ## Exercise 5: Mini challenge

# %%
print (" My name is Ukachi Victor")
print ("my dream career is Data Analyst")
print ("my country is Nigeria")
# Out:
#  My name is Ukachi Victor
# my dream career is Data Analyst
# my country is Nigeria

# %%
print (25+75)
# Out:
# 100

# %%
print (40//6)
# Out:
# 6

# %%
print (8**2)
# Out:
# 64

# %%
# this line is a comment, to display my name
print ("Ukachi Victor")
# Out:
# Ukachi Victor

# %%
#this line is a comment that displays my state of residence
print ("Lagos")
# Out:
# Lagos

# %%
#this line is a comments that displays the name of my laptop
print ("Dell")
# Out:
# Dell

# %% [markdown]
# # THANK YOU COACH FOR TAKING YOUR TIME TO TEACH US ALL THESE
